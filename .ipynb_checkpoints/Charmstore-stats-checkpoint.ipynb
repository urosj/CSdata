# %% [markdown]
# Code that downloads the information about charm uploads.

# %%
import json
import sys
import requests
from datetime import datetime
from datetime import timedelta

CHARMSTORE_URL = 'https://api.jujucharms.com/charmstore/v5'
CHANGES_URL = '/changes/published?'

def download_stats(start_date_str, end_date_str, interval, arg_output):
    start_date = datetime.strptime(start_date_str, '%Y-%m-%d')
    end_date = datetime.strptime(end_date_str, '%Y-%m-%d')

    data = []

    while start_date <= end_date:
        eow = start_date + timedelta(days=interval-1)
        param1 = start_date.strftime('%Y-%m-%d')
        param2 = eow.strftime('%Y-%m-%d')
        print(param1, param2)

        cs_data = {}
        cs_data["start"] = param1
        cs_data["stop"] = param2

        url = CHARMSTORE_URL+CHANGES_URL+"start="+param1+"&stop="+param2
        #print url
        r = requests.get(url)	
        uploads = {}
        uploads["date"]=param1
        uploads["charms"]=r.json()
        data.append(uploads)

        start_date = eow + timedelta(days=1)

    f = open(arg_output, "w")
    f.write(json.dumps(data))

# %% [markdown]
# Let's get data for two days, October 18th and 19th 2018. Write it out to test-changes.json.

# %%
download_stats("2018-10-18", "2018-10-19", 1, "test-changes.json")
# Out:
# 2018-10-18 2018-10-18
# 2018-10-19 2018-10-19

# %%
with open('test-changes.json') as f:
    data = json.load(f)

# %%
print(data)
# Out:
# [{'date': '2018-10-18', 'charms': [{'Id': 'cs:~containers/calico-175', 'PublishTime': '2018-10-18T23:45:00.715Z'}, {'Id': 'cs:~containers/kubernetes-master-233', 'PublishTime': '2018-10-18T23:40:23.424Z'}, {'Id': 'cs:~containers/canal-164', 'PublishTime': '2018-10-18T23:30:39.19Z'}, {'Id': 'cs:~containers/kubernetes-worker-252', 'PublishTime': '2018-10-18T23:27:06.002Z'}, {'Id': 'cs:~containers/easyrsa-126', 'PublishTime': '2018-10-18T23:23:50.572Z'}, {'Id': 'cs:~containers/flannel-154', 'PublishTime': '2018-10-18T23:18:57.439Z'}, {'Id': 'cs:~containers/kubernetes-e2e-182', 'PublishTime': '2018-10-18T23:13:01.963Z'}, {'Id': 'cs:~containers/kubeapi-load-balancer-175', 'PublishTime': '2018-10-18T23:11:11.911Z'}, {'Id': 'cs:~containers/calico-174', 'PublishTime': '2018-10-18T22:45:04.569Z'}, {'Id': 'cs:~containers/kubernetes-master-232', 'PublishTime': '2018-10-18T22:40:37.579Z'}, {'Id': 'cs:~containers/easyrsa-125', 'PublishTime': '2018-10-18T22:34:58.38Z'}, {'Id': 'cs:~containers/canal-163', 'PublishTime': '2018-10-18T22:30:33.467Z'}, {'Id': 'cs:~containers/kubernetes-worker-251', 'PublishTime': '2018-10-18T22:27:04.484Z'}, {'Id': 'cs:~containers/kubernetes-e2e-181', 'PublishTime': '2018-10-18T22:13:03.173Z'}, {'Id': 'cs:~containers/kubeapi-load-balancer-174', 'PublishTime': '2018-10-18T22:11:11.142Z'}, {'Id': 'cs:~containers/calico-173', 'PublishTime': '2018-10-18T21:45:01.9Z'}, {'Id': 'cs:~containers/etcd-218', 'PublishTime': '2018-10-18T21:42:36.212Z'}, {'Id': 'cs:~containers/kubernetes-master-231', 'PublishTime': '2018-10-18T21:40:14.043Z'}, {'Id': 'cs:~containers/canal-162', 'PublishTime': '2018-10-18T21:30:33.227Z'}, {'Id': 'cs:~containers/kubernetes-worker-250', 'PublishTime': '2018-10-18T21:27:22.664Z'}, {'Id': 'cs:~containers/kubernetes-e2e-180', 'PublishTime': '2018-10-18T21:12:55.984Z'}, {'Id': 'cs:~containers/kubeapi-load-balancer-173', 'PublishTime': '2018-10-18T21:11:07.133Z'}, {'Id': 'cs:~containers/calico-172', 'PublishTime': '2018-10-18T20:50:17.974Z'}, {'Id': 'cs:~containers/kubernetes-master-230', 'PublishTime': '2018-10-18T20:49:00.515Z'}, {'Id': 'cs:~containers/canal-161', 'PublishTime': '2018-10-18T20:46:40.594Z'}, {'Id': 'cs:~containers/kubernetes-worker-249', 'PublishTime': '2018-10-18T20:45:13.43Z'}, {'Id': 'cs:~containers/etcd-217', 'PublishTime': '2018-10-18T20:42:12.094Z'}, {'Id': 'cs:~containers/flannel-153', 'PublishTime': '2018-10-18T20:18:55.94Z'}, {'Id': 'cs:~containers/easyrsa-124', 'PublishTime': '2018-10-18T20:14:30.625Z'}, {'Id': 'cs:~containers/kubernetes-e2e-179', 'PublishTime': '2018-10-18T20:12:56.114Z'}, {'Id': 'cs:~containers/kubeapi-load-balancer-172', 'PublishTime': '2018-10-18T20:11:08.516Z'}, {'Id': 'cs:~containers/kubernetes-master-229', 'PublishTime': '2018-10-18T20:02:57.062Z'}, {'Id': 'cs:~containers/flannel-152', 'PublishTime': '2018-10-18T19:53:59.574Z'}, {'Id': 'cs:~containers/kubernetes-e2e-178', 'PublishTime': '2018-10-18T19:53:00.058Z'}, {'Id': 'cs:~containers/kubeapi-load-balancer-171', 'PublishTime': '2018-10-18T19:51:13.035Z'}, {'Id': 'cs:~containers/calico-171', 'PublishTime': '2018-10-18T19:45:17.105Z'}, {'Id': 'cs:~containers/kubernetes-master-228', 'PublishTime': '2018-10-18T19:44:46.28Z'}, {'Id': 'cs:~containers/canal-160', 'PublishTime': '2018-10-18T19:43:23.856Z'}, {'Id': 'cs:~containers/kubernetes-worker-248', 'PublishTime': '2018-10-18T19:42:18.837Z'}, {'Id': 'cs:~containers/docker-registry-0', 'PublishTime': '2018-10-18T19:28:27.764Z'}, {'Id': 'cs:~containers/flannel-151', 'PublishTime': '2018-10-18T19:18:53.533Z'}, {'Id': 'cs:~openstack-charmers-next/rabbitmq-server-311', 'PublishTime': '2018-10-18T19:15:33.267Z'}, {'Id': 'cs:~containers/kubernetes-e2e-177', 'PublishTime': '2018-10-18T19:13:09.142Z'}, {'Id': 'cs:~containers/kubeapi-load-balancer-170', 'PublishTime': '2018-10-18T19:11:21.178Z'}, {'Id': 'cs:~containers/bundle/canonical-kubernetes-canal-199', 'PublishTime': '2018-10-18T19:03:39.226Z'}, {'Id': 'cs:~containers/bundle/kubernetes-calico-216', 'Publ ...

# %%
download_stats("2018-01-01", "2018-10-19", 1, "uploads.json")
# Out:
# 2018-01-01 2018-01-01
# 2018-01-02 2018-01-02
# 2018-01-03 2018-01-03
# 2018-01-04 2018-01-04
# 2018-01-05 2018-01-05
# 2018-01-06 2018-01-06
# 2018-01-07 2018-01-07
# 2018-01-08 2018-01-08
# 2018-01-09 2018-01-09
# 2018-01-10 2018-01-10
# 2018-01-11 2018-01-11
# 2018-01-12 2018-01-12
# 2018-01-13 2018-01-13
# 2018-01-14 2018-01-14
# 2018-01-15 2018-01-15
# 2018-01-16 2018-01-16
# 2018-01-17 2018-01-17
# 2018-01-18 2018-01-18
# 2018-01-19 2018-01-19
# 2018-01-20 2018-01-20
# 2018-01-21 2018-01-21
# 2018-01-22 2018-01-22
# 2018-01-23 2018-01-23
# 2018-01-24 2018-01-24
# 2018-01-25 2018-01-25
# 2018-01-26 2018-01-26
# 2018-01-27 2018-01-27
# 2018-01-28 2018-01-28
# 2018-01-29 2018-01-29
# 2018-01-30 2018-01-30
# 2018-01-31 2018-01-31
# 2018-02-01 2018-02-01
# 2018-02-02 2018-02-02
# 2018-02-03 2018-02-03
# 2018-02-04 2018-02-04
# 2018-02-05 2018-02-05
# 2018-02-06 2018-02-06
# 2018-02-07 2018-02-07
# 2018-02-08 2018-02-08
# 2018-02-09 2018-02-09
# 2018-02-10 2018-02-10
# 2018-02-11 2018-02-11
# 2018-02-12 2018-02-12
# 2018-02-13 2018-02-13
# 2018-02-14 2018-02-14
# 2018-02-15 2018-02-15
# 2018-02-16 2018-02-16
# 2018-02-17 2018-02-17
# 2018-02-18 2018-02-18
# 2018-02-19 2018-02-19
# 2018-02-20 2018-02-20
# 2018-02-21 2018-02-21
# 2018-02-22 2018-02-22
# 2018-02-23 2018-02-23
# 2018-02-24 2018-02-24
# 2018-02-25 2018-02-25
# 2018-02-26 2018-02-26
# 2018-02-27 2018-02-27
# 2018-02-28 2018-02-28
# 2018-03-01 2018-03-01
# 2018-03-02 2018-03-02
# 2018-03-03 2018-03-03
# 2018-03-04 2018-03-04
# 2018-03-05 2018-03-05
# 2018-03-06 2018-03-06
# 2018-03-07 2018-03-07
# 2018-03-08 2018-03-08
# 2018-03-09 2018-03-09
# 2018-03-10 2018-03-10
# 2018-03-11 2018-03-11
# 2018-03-12 2018-03-12
# 2018-03-13 2018-03-13
# 2018-03-14 2018-03-14
# 2018-03-15 2018-03-15
# 2018-03-16 2018-03-16
# 2018-03-17 2018-03-17
# 2018-03-18 2018-03-18
# 2018-03-19 2018-03-19
# 2018-03-20 2018-03-20
# 2018-03-21 2018-03-21
# 2018-03-22 2018-03-22
# 2018-03-23 2018-03-23
# 2018-03-24 2018-03-24
# 2018-03-25 2018-03-25
# 2018-03-26 2018-03-26
# 2018-03-27 2018-03-27
# 2018-03-28 2018-03-28
# 2018-03-29 2018-03-29
# 2018-03-30 2018-03-30
# 2018-03-31 2018-03-31
# 2018-04-01 2018-04-01
# 2018-04-02 2018-04-02
# 2018-04-03 2018-04-03
# 2018-04-04 2018-04-04
# 2018-04-05 2018-04-05
# 2018-04-06 2018-04-06
# 2018-04-07 2018-04-07
# 2018-04-08 2018-04-08
# 2018-04-09 2018-04-09
# 2018-04-10 2018-04-10
# 2018-04-11 2018-04-11
# 2018-04-12 2018-04-12
# 2018-04-13 2018-04-13
# 2018-04-14 2018-04-14
# 2018-04-15 2018-04-15
# 2018-04-16 2018-04-16
# 2018-04-17 2018-04-17
# 2018-04-18 2018-04-18
# 2018-04-19 2018-04-19
# 2018-04-20 2018-04-20
# 2018-04-21 2018-04-21
# 2018-04-22 2018-04-22
# 2018-04-23 2018-04-23
# 2018-04-24 2018-04-24
# 2018-04-25 2018-04-25
# 2018-04-26 2018-04-26
# 2018-04-27 2018-04-27
# 2018-04-28 2018-04-28
# 2018-04-29 2018-04-29
# 2018-04-30 2018-04-30
# 2018-05-01 2018-05-01
# 2018-05-02 2018-05-02
# 2018-05-03 2018-05-03
# 2018-05-04 2018-05-04
# 2018-05-05 2018-05-05
# 2018-05-06 2018-05-06
# 2018-05-07 2018-05-07
# 2018-05-08 2018-05-08
# 2018-05-09 2018-05-09
# 2018-05-10 2018-05-10
# 2018-05-11 2018-05-11
# 2018-05-12 2018-05-12
# 2018-05-13 2018-05-13
# 2018-05-14 2018-05-14
# 2018-05-15 2018-05-15
# 2018-05-16 2018-05-16
# 2018-05-17 2018-05-17
# 2018-05-18 2018-05-18
# 2018-05-19 2018-05-19
# 2018-05-20 2018-05-20
# 2018-05-21 2018-05-21
# 2018-05-22 2018-05-22
# 2018-05-23 2018-05-23
# 2018-05-24 2018-05-24
# 2018-05-25 2018-05-25
# 2018-05-26 2018-05-26
# 2018-05-27 2018-05-27
# 2018-05-28 2018-05-28
# 2018-05-29 2018-05-29
# 2018-05-30 2018-05-30
# 2018-05-31 2018-05-31
# 2018-06-01 2018-06-01
# 2018-06-02 2018-06-02
# 2018-06-03 2018-06-03
# 2018-06-04 2018-06-04
# 2018-06-05 2018-06-05
# 2018-06-06 2018-06-06
# 2018-06-07 2018-06-07
# 2018-06-08 2018-06-08
# 2018-06-09 2018-06-09
# 2018-06-10 2018-06-10
# 2018-06-11 2018-06-11
# 2018-06-12 2018-06-12
# 2018-06-13 2018-06-13
# 2018-06-14 2018-06-14
# 2018-06-15 2018-06-15
# 2018-06-16 2018-06-16
# 2018-06-17 2018-06-17
# 2018-06-18 2018-06-18
# 2018-06-19 2018-06-19
# 2018-06-20 2018-06-20
# 2018-06-21 2018-06-21
# 2018-06-22 2018-06-22
# 2018-06-23 2018-06-23
# 2018-06-24 2018-06-24
# 2018-06-25 2018-06-25
# 2018-06-26 2018-06-26
# 2018-06-27 2018-06-27
# 2018-06-28 2018-06-28
# 2018-06-29 2018-06-29
# 2018-06-30 2018-06-30
# 2018-07-01 2018-07-01
# 2018-07-02 2018-07-02
# 2018-07-03 2018-07-03
# 2018-07-04 2018-07-04
# 2018-07-05 2018-07-05
# 2018-07-06 2018-07-06
# 2018-07-07 2018-07-07
# 2018-07-08 2018-07-08
# 2018-07-09 2018-07-09
# 2018-07-10 2018-07-10
# 2018-07-11 2018-07-11
# 2018-07-12 2018-07-12
# 2018-07-13 2018-07-13
# 2018-07-14 2018-07-14
# 2018-07-15 2018-07-15
# 2018-07-16 2018-07-16
# 2018-07-17 2018-07-17
# 2018-07-18 2018-07-18
# 2018-07-19 2018-07-19
# 2018-07-20 2018-07-20
# 2018-07-21 2018-07-21
# 2018-07-22 2018-07-22
# 2018-07-23 2018-07-23
# 2018-07-24 2018-07-24
# 2018-07-25 2018-07-25
# 2018-07-26 2018-07-26
# 2018-07-27 2018-07-27
# 2018-07-28 2018-07-28
# 2018-07-29 2018-07-29
# 2018-07-30 2018-07-30
# 2018-07-31 2018-07-31
# 2018-08-01 2018-08-01
# 2018-08-02 2018-08-02
# 2018-08-03 2018-08-03
# 2018-08-04 2018-08-04
# 2018-08-05 2018-08-05
# 2018-08-06 2018-08-06
# 2018-08-07 2018-08-07
# 2018-08-08 2018-08-08
# 2018-08-09 2018-08-09
# 2018-08-10 2018-08-10
# 2018-08-11 2018-08-11
# 2018-08-12 2018-08-12
# 2018-08-13 2018-08-13
# 2018-08-14 2018-08-14
# 2018-08-15 2018-08-15
# 2018-08-16 2018-08-16
# 2018-08-17 2018-08-17
# 2018-08-18 2018-08-18
# 2018-08-19 2018-08-19
# 2018-08-20 2018-08-20
# 2018-08-21 2018-08-21
# 2018-08-22 2018-08-22
# 2018-08-23 2018-08-23
# 2018-08-24 2018-08-24
# 2018-08-25 2018-08-25
# 2018-08-26 2018-08-26
# 2018-08-27 2018-08-27
# 2018-08-28 2018-08-28
# 2018-08-29 2018-08-29
# 2018-08-30 2018-08-30
# 2018-08-31 2018-08-31
# 2018-09-01 2018-09-01
# 2018-09-02 2018-09-02
# 2018-09-03 2018-09-03
# 2018-09-04 2018-09-04
# 2018-09-05 2018-09-05
# 2018-09-06 2018-09-06
# 2018-09-07 2018-09-07
# 2018-09-08 2018-09-08
# 2018-09-09 2018-09-09
# 2018-09-10 2018-09-10
# 2018-09-11 2018-09-11
# 2018-09-12 2018-09-12
# 2018-09-13 2018-09-13
# 2018-09-14 2018-09-14
# 2018-09-15 2018-09-15
# 2018-09-16 2018-09-16
# 2018-09-17 2018-09-17
# 2018-09-18 2018-09-18
# 2018-09-19 2018-09-19
# 2018-09-20 2018-09-20
# 2018-09-21 2018-09-21
# 2018-09-22 2018-09-22
# 2018-09-23 2018-09-23
# 2018-09-24 2018-09-24
# 2018-09-25 2018-09-25
# 2018-09-26 2018-09-26
# 2018-09-27 2018-09-27
# 2018-09-28 2018-09-28
# 2018-09-29 2018-09-29
# 2018-09-30 2018-09-30
# 2018-10-01 2018-10-01
# 2018-10-02 2018-10-02
# 2018-10-03 2018-10-03
# 2018-10-04 2018-10-04
# 2018-10-05 2018-10-05
# 2018-10-06 2018-10-06
# 2018-10-07 2018-10-07
# 2018-10-08 2018-10-08
# 2018-10-09 2018-10-09
# 2018-10-10 2018-10-10
# 2018-10-11 2018-10-11
# 2018-10-12 2018-10-12
# 2018-10-13 2018-10-13
# 2018-10-14 2018-10-14
# 2018-10-15 2018-10-15
# 2018-10-16 2018-10-16
# 2018-10-17 2018-10-17
# 2018-10-18 2018-10-18
# 2018-10-19 2018-10-19

# %%
with open('uploads.json') as f:
    data = json.load(f)

# %% [markdown]
# Now we have JSON data for uploads. For each item, map the date to the number of uploads for that date, getting two arrays: array of dates, and array of number of uploads.

# %%
dates = []
uploads = []
num_uploads = []
for d in data:
    dates.append(d['date'])
    uploads.append(d['charms'])
    num_uploads.append(len(d['charms']))
    
#print(dates)
print(num_uploads)
# Out:
# [0, 2, 5, 10, 20, 8, 3, 13, 3, 20, 4, 29, 0, 0, 2, 21, 4, 7, 41, 16, 14, 18, 21, 44, 31, 12, 9, 1, 5, 25, 20, 15, 26, 5, 4, 7, 11, 41, 37, 22, 1, 13, 22, 21, 21, 15, 17, 4, 4, 12, 18, 26, 50, 17, 17, 8, 13, 24, 23, 15, 7, 6, 0, 26, 31, 28, 87, 43, 18, 0, 17, 5, 15, 20, 18, 0, 1, 15, 19, 22, 21, 35, 0, 21, 8, 4, 10, 14, 29, 9, 2, 2, 49, 32, 6, 22, 6, 0, 17, 18, 21, 38, 20, 6, 2, 40, 31, 19, 11, 26, 4, 6, 34, 27, 55, 38, 32, 14, 10, 24, 43, 24, 19, 32, 15, 7, 9, 36, 55, 21, 42, 9, 1, 68, 38, 43, 12, 15, 4, 4, 6, 15, 7, 6, 1, 0, 2, 16, 9, 14, 6, 17, 0, 0, 13, 25, 20, 23, 14, 0, 0, 7, 49, 16, 13, 49, 1, 0, 25, 8, 12, 9, 5, 1, 0, 28, 21, 25, 34, 25, 12, 0, 26, 32, 17, 22, 23, 15, 0, 10, 40, 79, 32, 22, 0, 1, 62, 30, 21, 57, 22, 7, 6, 11, 16, 13, 13, 11, 2, 6, 28, 16, 24, 13, 24, 5, 4, 41, 20, 15, 26, 32, 17, 14, 27, 36, 39, 27, 23, 5, 6, 42, 30, 14, 11, 3, 3, 1, 20, 54, 116, 151, 35, 14, 17, 22, 48, 47, 88, 35, 11, 9, 16, 83, 16, 10, 21, 12, 22, 15, 21, 24, 66, 25, 1, 18, 35, 33, 30, 28, 62, 0, 0, 38, 26, 86, 76, 36, 1, 1, 7, 28, 64, 40, 21, 0, 2, 16, 40, 12, 127, 104]

# %% [markdown]
# Let's export the data, so that we can load it later with pandas.

# %%
import pandas as pd
import numpy as np

a = np.array(dates)
b = np.array(num_uploads)
df = pd.DataFrame({"date" : a, "num_uploads" : b})
df.to_csv("num-uploads.csv", index=False)

# %% [markdown]
# Let's load the data and print out some info about it.

# %%
uploads_data = pd.read_csv("num-uploads.csv")
uploads_data.head()
# Out:
#          date  num_uploads
# 0  2018-01-01            0
# 1  2018-01-02            2
# 2  2018-01-03            5
# 3  2018-01-04           10
# 4  2018-01-05           20

# %%
uploads_data.info
# Out:
# <bound method DataFrame.info of            date  num_uploads
# 0    2018-01-01            0
# 1    2018-01-02            2
# 2    2018-01-03            5
# 3    2018-01-04           10
# 4    2018-01-05           20
# 5    2018-01-06            8
# 6    2018-01-07            3
# 7    2018-01-08           13
# 8    2018-01-09            3
# 9    2018-01-10           20
# 10   2018-01-11            4
# 11   2018-01-12           29
# 12   2018-01-13            0
# 13   2018-01-14            0
# 14   2018-01-15            2
# 15   2018-01-16           21
# 16   2018-01-17            4
# 17   2018-01-18            7
# 18   2018-01-19           41
# 19   2018-01-20           16
# 20   2018-01-21           14
# 21   2018-01-22           18
# 22   2018-01-23           21
# 23   2018-01-24           44
# 24   2018-01-25           31
# 25   2018-01-26           12
# 26   2018-01-27            9
# 27   2018-01-28            1
# 28   2018-01-29            5
# 29   2018-01-30           25
# ..          ...          ...
# 262  2018-09-20           66
# 263  2018-09-21           25
# 264  2018-09-22            1
# 265  2018-09-23           18
# 266  2018-09-24           35
# 267  2018-09-25           33
# 268  2018-09-26           30
# 269  2018-09-27           28
# 270  2018-09-28           62
# 271  2018-09-29            0
# 272  2018-09-30            0
# 273  2018-10-01           38
# 274  2018-10-02           26
# 275  2018-10-03           86
# 276  2018-10-04           76
# 277  2018-10-05           36
# 278  2018-10-06            1
# 279  2018-10-07            1
# 280  2018-10-08            7
# 281  2018-10-09           28
# 282  2018-10-10           64
# 283  2018-10-11           40
# 284  2018-10-12           21
# 285  2018-10-13            0
# 286  2018-10-14            2
# 287  2018-10-15           16
# 288  2018-10-16           40
# 289  2018-10-17           12
# 290  2018-10-18          127
# 291  2018-10-19          104
#
# [292 rows x 2 columns]>

# %%
uploads_data['num_uploads'].plot(kind="bar", figsize=(50,15))

# %%
import matplotlib.pyplot as plt
uploads_data.hist(bins=50, figsize=(20,15))
plt.show()

# %%
uploads_data['num_uploads'].agg([pd.np.min, pd.np.max, pd.np.mean, pd.np.sum])
# Out:
# amin       0.000000
# amax     151.000000
# mean      21.099315
# sum     6161.000000
# Name: num_uploads, dtype: float64

# %%
def split_name(charm):
    #print(charm)
    n = charm.replace('cs:~','').split('/')
    nn = n[-1].split('-')
    del(nn[-1])
    charm_name = "-".join(nn)
    #print(n[0], charm_name)
    return n[0], charm_name

charmers = []
charms = []

#print(uploads)
for day in uploads:
    for upload in day:
        charm = upload['Id']
        charmer, charm_name = split_name(charm)
        charmers.append(charmer)
        charms.append(charm_name)
        
c = np.array(charmers)
d = np.array(charms)
df2 = pd.DataFrame({"charmer" : c, "application" : d})
df2.to_csv("charm-uploads.csv", index=False)

# %%
print(df2["charmer"].unique())
# Out:
# ['ce-hyperscale' 'openstack-charmers-next' 'jamesbeedy' 'mskalka'
#  'openstack-charmers' 'containers' 'omnivector' 'james-page' 'rharding'
#  'csd-garr' 'gnuoy' 'ryeterrell' 'juju-gui' 'filebeat-charmers' 'dmitriis'
#  'boucherv29' 'admcleod' 'canonical-bootstack' 'cynerva' 'nuvolasns'
#  'thedac' 'postgresql-charmers' 'elasticsearch-charmers' 'cmars'
#  'prometheus-charmers' 'telegraf-charmers' 'cplane-team' 'nrpe-charmers'
#  'graylog-charmers' 'nagios-charmers' 'influxdb-charmers' 'knobby'
#  'discourse-charmers' 'cassandra-charmers' 'marcoceppi'
#  'livepatch-charmers' 'kwmonroe' 'openstack-dev-s' 'kos.tsakalozos'
#  'apache2-charmers' 'chris.sanders' 'haproxy-team' 'vtas-hyperscale-ci'
#  'ntp-team' 'paulgear' 'spiculecharms' 'landscape' 'vault-charmers'
#  'mthaddon' '1chb1n' 'canonical-solutions' 'tengu-team' 'bigdata-charmers'
#  'landscape-charmers' 'mongodb-charmers' 'mariosplivalo'
#  'chris.macnaughton' 'rogpeppe' 'jameinel' 'petevg' 'slurm-charmers'
#  'autocert-charmers' 'memcached-team' 'sdn-charmers'
#  'squid-reverseproxy-charmers' 'peter-sabaini' 'freyes' 'johnsca'
#  'cassiocassio' 'carpalex' 'wiilink' 'mysql-charmers' 'charmers'
#  'szeestraten' 'xavpaice' 'deej' 'nfs-charmers' 'sgiller'
#  'mailman3-charmers' 'hloeung' 'navid-nikaein' 'pjdc' 'oil-charms'
#  'fnordahl' 'ivoks' 'kj-kingj' 'alai' 'adriancampos' '6wind'
#  'apache-openid-charmers' 'juju-introspection-proxy-charmers' 'ecjones'
#  'frankban' 'axino' 'canonical-sysadmins' 'yellow' 'ae40515' 'afreiberger'
#  'pguimaraes' 'juju-qa' 'sentry-charmers' 'tcuthbert' 'elastisys'
#  'asbalderson' 'redis-charmers' 'ykato-aims' 'yoshikadokawa'
#  'narindergupta']

# %% [markdown]
# Number of charmers uploading the charms in the time period.

# %%
len(df2["charmer"].unique())
# Out:
# 108

# %%
df2.groupby(["charmer"]).count()
# Out:
#                              application
# charmer
# 1chb1n                                 5
# 6wind                                 11
# admcleod                               4
# adriancampos                           2
# ae40515                                1
# afreiberger                            1
# alai                                   3
# apache-openid-charmers                 2
# apache2-charmers                       4
# asbalderson                            1
# autocert-charmers                     16
# axino                                 37
# bigdata-charmers                     268
# boucherv29                             8
# canonical-bootstack                   30
# canonical-solutions                    4
# canonical-sysadmins                    1
# carpalex                               4
# cassandra-charmers                    19
# cassiocassio                           3
# ce-hyperscale                          1
# charmers                               1
# chris.macnaughton                     14
# chris.sanders                         39
# cmars                                  4
# containers                          2100
# cplane-team                           51
# csd-garr                              28
# cynerva                               76
# deej                                  23
# ...                                  ...
# openstack-dev-s                       25
# paulgear                              41
# peter-sabaini                          2
# petevg                                 2
# pguimaraes                            40
# pjdc                                   8
# postgresql-charmers                   26
# prometheus-charmers                   58
# redis-charmers                         2
# rharding                              21
# rogpeppe                               2
# ryeterrell                            34
# sdn-charmers                           6
# sentry-charmers                        7
# sgiller                                2
# slurm-charmers                         1
# spiculecharms                        232
# squid-reverseproxy-charmers            2
# szeestraten                            2
# tcuthbert                             11
# telegraf-charmers                     14
# tengu-team                            33
# thedac                                25
# vault-charmers                         1
# vtas-hyperscale-ci                     2
# wiilink                                4
# xavpaice                              29
# yellow                                 1
# ykato-aims                             2
# yoshikadokawa                          2
#
# [108 rows x 1 columns]

# %%
charmer_count = df2.groupby(["charmer"]).count()
charmer_count.to_csv("charmer-count.cvs")

# %%
df2.groupby(["charmer"]).count().plot(kind="bar", figsize=(30,15))

# %%
print(df2["application"].unique())
# Out:
# ['scalebot-jenkins' 'rabbitmq-server' 'heat' 'ceilometer' 'keystone'
#  'elasticsearch' 'kibana' 'cinder-three-par' 'nova-compute'
#  'nova-cloud-controller' 'hacluster' 'percona-cluster' 'keystone-ldap'
#  'kubernetes-core' 'thelounge' 'ceph-osd' 'openstack-kpi-scripts'
#  'jujushell' 'neutron-api' 'designate' 'openstack-dashboard'
#  'canonical-kubernetes-canal' 'kubernetes-calico'
#  'canonical-kubernetes-elastic' 'canonical-kubernetes' 'kubernetes-worker'
#  'kubeapi-load-balancer' 'filebeat' 'openldap' 'keepalived' 'magpie'
#  'ceph-mon' 'etcd' 'canal' 'kubernetes-e2e' 'kubernetes-master' 'calico'
#  'cinder' 'neutron-openvswitch' 'glance' 'neutron-gateway'
#  'openstack-service-checks' 'flannel' 'easyrsa' 'policy-routing'
#  'rpfilter' 'barbican' 'cinder-ceph' 'cinder-backup' 'ceilometer-agent'
#  'odl-controller' 'ceph-radosgw' 'swift-storage' 'swift-proxy'
#  'nova-compute-proxy' 'lxd' 'ceph-proxy' 'postgresql' 'tempest'
#  'barbican-softhsm' 'ceph-fs' 'manila' 'manila-generic' 'neutron-api-odl'
#  'gnocchi' 'openvswitch-odl' 'tor-bridge' 'tor-hidden' 'tor-relay'
#  'prometheus-ceph-exporter' 'telegraf' 'designate-bind' 'aodh'
#  'cplane-controller' 'oracle' 'nrpe' 'neutron-openvswitch-cplane'
#  'graylog' 'nagios' 'prometheus-openstack-exporter' 'influxdb' 'topbeat'
#  'openstack-telemetry-bionic-queens' 'openstack-base-bionic-queens'
#  'ceph-base-bionic-luminous' 'openstack-telemetry-xenial-queens'
#  'openstack-base-xenial-queens' 'discourse' 'defaultgw' 'elk-stack'
#  'logstash' 'grafana' 'cassandra' 'ubuntu' 'canonical-livepatch'
#  'owncloud' 'sysconfig' 'cinder-storpool' 'storpool-block'
#  'neutron-api-cplane' 'apache2' 'panko' 'ceph' 'haproxy'
#  'hyperscale-controller' 'ntp' 'unattended' 'maas' 'apache-drill'
#  'basic-auth-service' 'vault' 'saiku-enterprise' 'moodle' 'pgbouncer'
#  'apache-solr' 'postgresql-client' 'serial-vault-bundle'
#  'serial-vault-selfhosted' 'ssl-termination-proxy' 'hadoop-slave'
#  'kibana-elasticsearch' 'hive' 'zookeeper' 'zeppelin' 'spark' 'pig'
#  'mahout' 'kafka' 'hbase' 'hadoop-resourcemanager' 'hadoop-plugin'
#  'hadoop-namenode' 'spark-processing' 'hadoop-kafka' 'hadoop-hbase'
#  'hadoop-spark' 'hadoop-processing' 'hadoop-client' 'landscape-client'
#  'saiku-drill' 'mongodb' 'test-perm' 'mysql' 'dsnviewer'
#  'thingworx-foundation-server' 'prometheus2' 'open-foam'
#  'openstack-telemetry' 'openstack-base' 'ceph-base' 'nfs-server'
#  'ubuntu-lite' 'luigi-server' 'ssl-termination-proxy-example'
#  'ssl-termination-fqdn' 'neutron-api-subordinate-shim'
#  'designate-neutron-dns' 'ogr-compute-cplane' 'openstack-lxd'
#  'cplane-neutron-ovs-controller-with-ogr-node-oracle-rac'
#  'cplane-neutron-ovs-controller-with-ogr-node-oracle12c-single'
#  'cplane-neutron-ovs-controller-with-ogr-node-oracle'
#  'cplane-neutron-ovs-controller-with-ogr-node' 'cinder-netapp' 'congress'
#  'slurm-controller' 'canonical-kubernetes-nvidia' 'autocert'
#  'neutron-dynamic-routing' 'quagga' 'memcached' 'saiku-drill-hadoop'
#  'neutron-api-contrail' 'contrail-webui' 'contrail-analytics'
#  'neutron-contrail' 'contrail-control' 'contrail-configuration'
#  'juju-storage' 'squid-reverseproxy' 'oracle-12c' 'salt-minion'
#  'salt-master' 'juju-lxd' 'redis' 'hadoop-spark-jupyter-conda'
#  'jupyter-notebook' 'conda' 'sabnzbd' 'sonarr' 'couchpotato' 'file-server'
#  'plex' 'duplicati' 'glance-simplestreams-sync-next' 'cinder-proxy-header'
#  'aws' 'glance-simplestreams-sync' 'test' 'landscape-server' 'slurm-node'
#  'slurm-hpc-min' 'twister' 'vnflcv' 'test-vault-kv' 'sftp-server'
#  'kibanaspirent' 'prometheus-grok-exporter' 'vanilla' 'kapacitor'
#  'arangodb' 'create-custom-data-flows' 'automate-spark-jobs'
#  'ceph-osd-aa-fixes' 'gcp' 'vault-auto-unlock' 'chronograf' 'sojobo-api'
#  'drill-hadoop' 'saiku-basic-sql' 'drill-hbase' 'controller-azure'
#  'controller-google' 'controller-aws' 'ceph-lxd' 'elk'
#  'keystone-saml-mellon' 'ceph-osd-udev-fixes' 'prometheus'
#  'ldap-test-fixture' 'nfs' 'cplane-msm-oracle-ha' 'cplane-msm-oracle-rac'
#  'cplane-msm-oracle12c-single' 'cplane-msm-oracle' 'cplane-msm'
#  'egk-stack' 'jenkins' 'mailman3-web' 'mailman3-core' 'flexran-rtc'
#  'll-mec' 'lxd-cluster' 'cqlsh' 'prometheus-alertmanager' 'slurm-openfoam'
#  'anssr-hadoop' 'anssr-data-engine' 'landscape-scalable' 'landscape-dense'
#  'landscape-dense-maas' 'weebl' 'ubuntu-devenv' 'gcp-integrator'
#  'aws-integrator' 'openstack-integrator' 'django' 'anssr-analytics'
#  'slurm-node-v2' 'slurm-controller-v2' 'index-paratus'
#  'neutron-openvswitch-bug1773353' 'neutron-gateway-bug1773353' 'sysctl'
#  'openstack-telemetry-xenial-pike' 'openstack-telemetry-xenial-ocata'
#  'openstack-telemetry-xenial-newton'
#  'openstack-refstack-xenial-pike-ppc64el-alt'
#  'openstack-refstack-xenial-pike'
#  'openstack-refstack-xenial-ocata-ppc64el-alt'
#  'openstack-refstack-xenial-ocata' 'openstack-base-xenial-pike'
#  'openstack-base-xenial-ocata' 'openstack-base-xenial-newton'
#  'openstack-base-xenial-mitaka' 'openstack-base-spaces'
#  'ceph-base-xenial-luminous' 'ceph-base-xenial-jewel' 'lldpd' 'mattermost'
#  'snmpd' 'reverseproxy' 'senlin' 'nova-cell-controller' 'hue' 'oozie'
#  'prometheus-snmp-exporter' 'prometheus-pushgateway'
#  'prometheus-blackbox-exporter' 'datadog-agent' 'cloudkitty-charm'
#  'virtual-accelerator-network' 'virtual-accelerator-compute'
#  'fuse-nfs-client' 'cinder-vnx-fc' 'ganglia-node' 'kubernetes-keystone'
#  'apache-openid' 'prometheus-libvirt-exporter' 'juju-introspection-proxy'
#  'keystone-ico' 'storpool-candleholder' 'ceph-osd-bug1783308'
#  'trilio-horizon-plugin' 'trilio-data-mover-api' 'trilio-data-mover'
#  'glance-sync-master' 'glance-sync-slave' 'ganglia' 'uosci-dashboard'
#  'realtime-syslog-analytics' 'ubuntu-series-upgrade' 'edwood'
#  'bcache-tuning' 'sentry' 'docker-registry' 'vsphere-integrator'
#  'azure-integrator' 'landscape' 'neutron-arista' 'kubernetes-worker-o7k'
#  'kubernetes-master-o7k' 'openstack-integrator-test' 'wireguard' 'gitea'
#  'flask-test' 'lxd-profile-subordinate' 'lxd-profile' 'aws-elb'
#  'aodh-sf00182054' 'lxd-profile-fail' 'sentry-decoupled'
#  'gnocchi-sf00182054' 'charmscaler' 'ntpmaster' 'juju-controller'
#  'no-ubuntu-user' 'sentry-all-in-one' 'rsyslog-forwarder-ha' 'noop-centos'
#  'charms-clamav' 'oai-hss']

# %% [markdown]
# Number of applications loaded in the time period.

# %%
len(df2["application"].unique())
# Out:
# 342

# %%
df2.groupby(["application"]).count()
# Out:
#                               charmer
# application
# anssr-analytics                     1
# anssr-data-engine                   2
# anssr-hadoop                        3
# aodh                               46
# aodh-sf00182054                     1
# apache-drill                      117
# apache-openid                       2
# apache-solr                         1
# apache2                             4
# arangodb                            1
# autocert                           16
# automate-spark-jobs                 2
# aws                                 8
# aws-elb                             4
# aws-integrator                      6
# azure-integrator                    2
# barbican                           26
# barbican-softhsm                   17
# basic-auth-service                 12
# bcache-tuning                      10
# calico                            175
# canal                             154
# canonical-kubernetes              153
# canonical-kubernetes-canal        148
# canonical-kubernetes-elastic      129
# canonical-kubernetes-nvidia        10
# canonical-livepatch                14
# cassandra                          16
# ceilometer                         51
# ceilometer-agent                   28
# ...                               ...
# test                                4
# test-perm                           1
# test-vault-kv                       1
# thelounge                           1
# thingworx-foundation-server         1
# topbeat                             3
# tor-bridge                          1
# tor-hidden                          1
# tor-relay                           1
# trilio-data-mover                   3
# trilio-data-mover-api               3
# trilio-horizon-plugin               3
# twister                             1
# ubuntu                              3
# ubuntu-devenv                       1
# ubuntu-lite                         1
# ubuntu-series-upgrade               1
# unattended                          1
# uosci-dashboard                     3
# vanilla                             1
# vault                             131
# vault-auto-unlock                   1
# virtual-accelerator-compute         6
# virtual-accelerator-network         5
# vnflcv                              1
# vsphere-integrator                  2
# weebl                               1
# wireguard                           2
# zeppelin                           16
# zookeeper                          17
#
# [342 rows x 1 columns]

# %%
df2.groupby(["application"]).count().plot(kind="bar", figsize=(50,15))

# %%
app_count = df2.groupby(["application"]).count()
app_count.to_csv("app-count.csv")

# %%
df2.groupby(["charmer", "application"]).count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(1chb1n, designate-bind), (1chb1n, glance-simplestreams-sync), (1chb1n, nova-compute), (1chb1n, senlin), (6wind, virtual-accelerator-compute), (6wind, virtual-accelerator-network), (admcleod, magpie), (adriancampos, cinder-vnx-fc), (adriancampos, cloudkitty-charm), (ae40515, neutron-api-odl), (afreiberger, openstack-dashboard), (alai, kibana), (alai, landscape), (alai, landscape-server), (apache-openid-charmers, apache-openid), (apache2-charmers, apache2), (asbalderson, noop-centos), (autocert-charmers, autocert), (axino, redis), (axino, sentry), (axino, telegraf), (bigdata-charmers, hadoop-client), (bigdata-charmers, hadoop-hbase), (bigdata-charmers, hadoop-kafka), (bigdata-charmers, hadoop-namenode), (bigdata-charmers, hadoop-plugin), (bigdata-charmers, hadoop-processing), (bigdata-charmers, hadoop-resourcemanager), (bigdata-charmers, hadoop-slave), (bigdata-charmers, hadoop-spark), (bigdata-charmers, hbase), (bigdata-charmers, hive), (bigdata-charmers, kafka), (bigdata-charmers, mahout), (bigdata-charmers, pig), (bigdata-charmers, realtime-syslog-analytics), (bigdata-charmers, spark), (bigdata-charmers, spark-processing), (bigdata-charmers, zeppelin), (bigdata-charmers, zookeeper), (boucherv29, keepalived), (canonical-bootstack, filebeat), (canonical-bootstack, glance-sync-master), (canonical-bootstack, glance-sync-slave), (canonical-bootstack, juju-controller), (canonical-bootstack, juju-lxd), (canonical-bootstack, landscape-server), (canonical-bootstack, nrpe), (canonical-bootstack, openstack-service-checks), (canonical-bootstack, policy-routing), (canonical-bootstack, sysconfig), (canonical-solutions, serial-vault-bundle), (canonical-solutions, serial-vault-selfhosted), (canonical-sysadmins, ubuntu), (carpalex, kibanaspirent), (carpalex, twister), (carpalex, vnflcv), (cassandra-charmers, cassandra), (cassandra-charmers, cqlsh), (cassiocassio, mattermost), (cassiocassio, mongodb), (ce-hyperscale, scalebot-jenkins), (charmers, mysql), (chris.macnaughton, ceph-osd), (chris.macnaughton, fuse-nfs-client), (chris.macnaughton, ganglia), (chris.macnaughton, ganglia-node), (chris.macnaughton, gitea), (chris.macnaughton, haproxy), (chris.macnaughton, sysctl), (chris.macnaughton, uosci-dashboard), (chris.sanders, ceph), (chris.sanders, ceph-fs), (chris.sanders, ceph-mon), (chris.sanders, ceph-osd), (chris.sanders, couchpotato), (chris.sanders, duplicati), (chris.sanders, file-server), (chris.sanders, grafana), (chris.sanders, haproxy), (chris.sanders, openstack-dashboard), (chris.sanders, plex), (chris.sanders, prometheus-ceph-exporter), (chris.sanders, reverseproxy), (chris.sanders, sabnzbd), (chris.sanders, salt-master), (chris.sanders, salt-minion), (chris.sanders, sftp-server), (chris.sanders, sonarr), (chris.sanders, thingworx-foundation-server), (chris.sanders, wireguard), (cmars, kafka), (cmars, tor-bridge), (cmars, tor-hidden), (cmars, tor-relay), (containers, aws), (containers, aws-integrator), (containers, azure-integrator), (containers, calico), (containers, canal), ...]
#
# [562 rows x 0 columns]

# %%
grp = df2.groupby(["charmer", "application"]).count()
grp.to_csv("charmer-app-count.csv")

grp2 = df2.groupby(["application", "charmer"]).count()
grp2.to_csv("app-charmer-count.csv")

# %%
grp2.filter(like="kubernetes", axis=0)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(canonical-kubernetes, containers), (canonical-kubernetes-canal, containers), (canonical-kubernetes-elastic, containers), (canonical-kubernetes-nvidia, containers), (kubernetes-calico, containers), (kubernetes-calico, cynerva), (kubernetes-core, containers), (kubernetes-core, ykato-aims), (kubernetes-e2e, containers), (kubernetes-e2e, kos.tsakalozos), (kubernetes-e2e, ryeterrell), (kubernetes-keystone, csd-garr), (kubernetes-master, containers), (kubernetes-master, cynerva), (kubernetes-master, johnsca), (kubernetes-master, knobby), (kubernetes-master, kos.tsakalozos), (kubernetes-master, pguimaraes), (kubernetes-master, ryeterrell), (kubernetes-master-o7k, dmitriis), (kubernetes-worker, containers), (kubernetes-worker, cynerva), (kubernetes-worker, johnsca), (kubernetes-worker, knobby), (kubernetes-worker, kos.tsakalozos), (kubernetes-worker, pguimaraes), (kubernetes-worker, ryeterrell), (kubernetes-worker-o7k, dmitriis)]

# %%
grp.filter(like="spicule", axis=0)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(spiculecharms, anssr-analytics), (spiculecharms, anssr-data-engine), (spiculecharms, anssr-hadoop), (spiculecharms, apache-drill), (spiculecharms, apache-solr), (spiculecharms, drill-hadoop), (spiculecharms, drill-hbase), (spiculecharms, hue), (spiculecharms, oozie), (spiculecharms, saiku-basic-sql), (spiculecharms, saiku-drill), (spiculecharms, saiku-drill-hadoop), (spiculecharms, saiku-enterprise)]

# %%
df2.groupby(["charmer"]).count().filter(like="spicule", axis=0)
# Out:
#                application
# charmer
# spiculecharms          232
